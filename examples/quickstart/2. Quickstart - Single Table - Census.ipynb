# %%
import pandas as pd

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
columns = [
    'age',
    'workclass',
    'fnlwgt',
    'education',
    'education-num',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'capital-gain',
    'capital-loss',
    'hours-per-week',
    'native-country',
    'income'
]

# %%
df = pd.read_csv(url, names=columns)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
tables = {
    'census': df
}

# %%
metadata = {
    "path": "",
    "tables": [
        {
            "fields": [
                {
                    "name": "age",
                    "type": "number",
                    "subtype": "integer",
                },
                {
                    "name": "workclass",
                    "type": "categorical",
                    "subtype": "categorical",
                },
                {
                    "name": "fnlwgt",
                    "type": "number",
                    "subtype": "integer",
                },
                {
                    "name": "education",
                    "type": "categorical",
                    "subtype": "categorical",
                },
                {
                    "name": "education-num",
                    "type": "number",
                    "subtype": "integer",
                },
                {
                    "name": "marital-status",
                    "type": "categorical",
                    "subtype": "categorical",
                },
                {
                    "name": "occupation",
                    "type": "categorical",
                    "subtype": "categorical",
                },
                {
                    "name": "relationship",
                    "type": "categorical",
                    "subtype": "categorical",
                },
                {
                    "name": "race",
                    "type": "categorical",
                    "subtype": "categorical",
                },
                {
                    "name": "sex",
                    "type": "categorical",
                    "subtype": "categorical",
                },
                {
                    "name": "capital-gain",
                    "type": "number",
                    "subtype": "integer",
                },
                {
                    "name": "capital-loss",
                    "type": "number",
                    "subtype": "integer",
                },
                {
                    "name": "hours-per-week",
                    "type": "number",
                    "subtype": "integer",
                },
                {
                    "name": "native-country",
                    "type": "categorical",
                    "subtype": "categorical",
                },
                {
                    "name": "income",
                    "type": "categorical",
                    "subtype": "categorical",
                }
            ],
            "headers": True,
            "name": "census",
            "path": "census.csv",
            "use": True
        }
    ]
}

# %%
from sdv import SDV

sdv = SDV()
sdv.fit(metadata, tables)
# Out:
# 2019-10-25 09:11:14,158 - INFO - modeler - Modeling census
# 2019-10-25 09:11:14,381 - INFO - modeler - Modeling Complete

# %%
sampled = sdv.sample('census', num_rows=len(df))
sampled['census'].head()
# Out:
#    age          workclass  fnlwgt      education  education-num  \
# 0   31            Private   16200        HS-grad             11
# 1   51            Private  101711      Bachelors             11
# 2   63            Private  -66916   Some-college             11
# 3   43   Self-emp-not-inc  210920        7th-8th             13
# 4   31            Private  124384        HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married     Protective-serv         Husband   White   Male
# 1   Married-civ-spouse                   ?         Husband   White   Male
# 2        Never-married       Other-service         Husband   White   Male
# 3             Divorced   Machine-op-inspct       Own-child   White   Male
# 4        Never-married        Adm-clerical   Not-in-family   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          1011          -297              20   United-States   <=50K
# 1         -2854          -458              40   United-States   <=50K
# 2          3266           466              61   United-States   <=50K
# 3          -127          -323              48   United-States   <=50K
# 4         -3230          -297              23   United-States   <=50K
