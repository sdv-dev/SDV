# %%
from sdv import SDV

sdv = SDV()
sdv.fit('metadata.json')
# Out:
# 2019-10-25 08:55:16,687 - INFO - modeler - Modeling customers
# 2019-10-25 08:55:16,688 - INFO - metadata - Loading table customers
# 2019-10-25 08:55:16,708 - INFO - modeler - Modeling orders
# 2019-10-25 08:55:16,709 - INFO - metadata - Loading table orders
# 2019-10-25 08:55:16,713 - INFO - modeler - Modeling order_items
# 2019-10-25 08:55:16,714 - INFO - metadata - Loading table order_items
# 2019-10-25 08:55:17,373 - INFO - modeler - Modeling Complete

# %%
real = sdv.metadata.get_tables()

samples = sdv.sample_all(len(real['customers']), reset_primary_keys=True)
# Out:
# 2019-10-25 08:55:17,421 - INFO - metadata - Loading table customers
# 2019-10-25 08:55:17,425 - INFO - metadata - Loading table orders
# 2019-10-25 08:55:17,427 - INFO - metadata - Loading table order_items

# %%
samples['customers'].head()
# Out:
#    customer_id cust_postal_code  phone_number1  credit_limit country
# 0            0            11371     5738238120          1452  FRANCE
# 1            1            20166     6791930877           306   SPAIN
# 2            2            11371     4774461677          1143      UK
# 3            3            63145     3886242922           688      UK
# 4            4            20166     5030172728          1094  FRANCE

# %%
real['customers'].head()
# Out:
#    customer_id cust_postal_code  phone_number1  credit_limit country
# 0           50            11371     6175553295          1000      UK
# 1            4            63145     8605551835           500      US
# 2     97338810             6096     7035552143          1000  CANADA
# 3       630407            63145     7035552143          2000      US
# 4       826362            11371     6175553295          1000      UK

# %%
samples['orders'].head()
# Out:
#    order_id  customer_id  order_total
# 0         0            0          823
# 1         1            1          897
# 2         2            1         1365
# 3         3            1         1600
# 4         4            1          709

# %%
real['orders'].head()
# Out:
#    order_id  customer_id  order_total
# 0         1           50         2310
# 1         2            4         1507
# 2        10     97338810          730
# 3         6     55996144          730
# 4         3     55996144          939

# %%
samples['order_items'].head()
# Out:
#    order_item_id  order_id product_id  unit_price  quantity
# 0              0         0         10          32         1
# 1              1         0         10          65         4
# 2              2         0         10          57         1
# 3              3         0         10          65         3
# 4              4         0          6          70         3

# %%
real['order_items'].head()
# Out:
#    order_item_id  order_id product_id  unit_price  quantity
# 0            100        10          7          52         8
# 1            101         8          6         125         4
# 2            102         1          6         125         4
# 3            103         4          9         125         4
# 4            104         1          9         113         4
