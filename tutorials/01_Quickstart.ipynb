# %% [markdown]
# # Quickstart
#
# In this short tutorial we will guide you through a series of steps that will help you
# getting started using **SDV**.
#
# ## 1. Model the dataset using SDV
#
# To model a multi table, relational dataset, we follow two steps. In the first step, we will load
# the data and configures the meta data. In the second step, we will use the sdv API to fit and
# save a hierarchical model. We will cover these two steps in this section using an example dataset.
#
# ### Step 1: Load example data
#
# **SDV** comes with a toy dataset to play with, which can be loaded using the `sdv.load_demo`
# function:

# %%
# Setup logging and warnings
import logging;
logging.basicConfig(level=logging.INFO)
logging.getLogger().setLevel(level=logging.WARNING)
logging.getLogger('sdv').setLevel(level=logging.INFO)

import warnings
warnings.simplefilter("ignore")

# %%
from sdv import load_demo

metadata, tables = load_demo(metadata=True)

# %% [markdown]
# This will return two objects:
#
# 1. A `Metadata` object with all the information that **SDV** needs to know about the dataset.

# %%
metadata
# Out:
# Metadata
#   root_path: .
#   tables: ['users', 'sessions', 'transactions']
#   relationships:
#     sessions.user_id -> users.user_id
#     transactions.session_id -> sessions.session_id

# %%
metadata.visualize()

# %% [markdown]
# For more details about how to build the `Metadata` for your own dataset, please refer to the
# [Metadata](https://sdv-dev.github.io/SDV/metadata.html) section of the documentation.

# %% [markdown]
# 2. A dictionary containing three `pandas.DataFrames` with the tables described in the
# metadata object.

# %%
from sdv.utils import display_tables

display_tables(tables)
# Out:
# <table><tr><td><b>users</b></td><td><b>sessions</b></td><td><b>transactions</b></td></tr><tr><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>country</th>
#       <th>gender</th>
#       <th>age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>US</td>
#       <td>M</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>UK</td>
#       <td>F</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>ES</td>
#       <td>None</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>UK</td>
#       <td>M</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>US</td>
#       <td>F</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>DE</td>
#       <td>M</td>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>BG</td>
#       <td>F</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>ES</td>
#       <td>None</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>FR</td>
#       <td>F</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>UK</td>
#       <td>None</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>session_id</th>
#       <th>user_id</th>
#       <th>device</th>
#       <th>os</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>mobile</td>
#       <td>android</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>tablet</td>
#       <td>ios</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>1</td>
#       <td>tablet</td>
#       <td>android</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>2</td>
#       <td>mobile</td>
#       <td>android</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>4</td>
#       <td>mobile</td>
#       <td>ios</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>5</td>
#       <td>mobile</td>
#       <td>android</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>6</td>
#       <td>mobile</td>
#       <td>ios</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>6</td>
#       <td>tablet</td>
#       <td>ios</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>6</td>
#       <td>mobile</td>
#       <td>ios</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>8</td>
#       <td>tablet</td>
#       <td>ios</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>transaction_id</th>
#       <th>session_id</th>
#       <th>timestamp</th>
#       <th>amount</th>
#       <th>approved</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>2019-01-01 12:34:32</td>
#       <td>100.0</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>0</td>
#       <td>2019-01-01 12:42:21</td>
#       <td>55.3</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>1</td>
#       <td>2019-01-07 17:23:11</td>
#       <td>79.5</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>3</td>
#       <td>2019-01-10 11:08:57</td>
#       <td>112.1</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>5</td>
#       <td>2019-01-10 21:54:08</td>
#       <td>110.0</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>5</td>
#       <td>2019-01-11 11:21:20</td>
#       <td>76.3</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>7</td>
#       <td>2019-01-22 14:44:10</td>
#       <td>89.5</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>8</td>
#       <td>2019-01-23 10:14:09</td>
#       <td>132.1</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>9</td>
#       <td>2019-01-27 16:09:17</td>
#       <td>68.0</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>9</td>
#       <td>2019-01-29 12:10:48</td>
#       <td>99.9</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>

# %% [markdown]
# ### 2. Fit a model using the SDV API.
#
# First, we build a hierarchical statistical model of the data using **SDV**. For this we will
# create an instance of the `sdv.SDV` class and use its `fit` method.
#
# During this process, **SDV** will traverse across all the tables in your dataset following the
# primary key-foreign key relationships and learn the probability distributions of the values in
# the columns.

# %%
from sdv import SDV

sdv = SDV()
sdv.fit(metadata, tables)
# Out:
# 2020-08-05 10:37:11,976 - INFO - sdv.modeler - Modeling users
# 2020-08-05 10:37:11,977 - INFO - sdv.metadata - Loading transformer CategoricalTransformer for field country
# 2020-08-05 10:37:11,978 - INFO - sdv.metadata - Loading transformer CategoricalTransformer for field gender
# 2020-08-05 10:37:11,979 - INFO - sdv.metadata - Loading transformer NumericalTransformer for field age
# 2020-08-05 10:37:12,000 - INFO - sdv.modeler - Modeling sessions
# 2020-08-05 10:37:12,000 - INFO - sdv.metadata - Loading transformer CategoricalTransformer for field device
# 2020-08-05 10:37:12,001 - INFO - sdv.metadata - Loading transformer CategoricalTransformer for field os
# 2020-08-05 10:37:12,019 - INFO - sdv.modeler - Modeling transactions
# 2020-08-05 10:37:12,020 - INFO - sdv.metadata - Loading transformer DatetimeTransformer for field timestamp
# 2020-08-05 10:37:12,020 - INFO - sdv.metadata - Loading transformer NumericalTransformer for field amount
# 2020-08-05 10:37:12,020 - INFO - sdv.metadata - Loading transformer BooleanTransformer for field approved
# 2020-08-05 10:37:12,439 - INFO - sdv.modeler - Modeling Complete

# %% [markdown]
# ## 2. Sample data from the fitted model
#
# Once the modeling has finished you are ready to generate new synthetic data using the `sdv` instance that you have.
#
# For this, all you have to do is call the `sample_all` method from your instance passing the number of rows that you want to generate:

# %%
sampled = sdv.sample_all(10)

# %% [markdown]
# This will return a dictionary identical to the `tables` one that we passed to the SDV instance for learning, filled in with new synthetic data.
#
# **Note** that only the parent tables of your dataset will have the specified number of rows,
# as the number of child rows that each row in the parent table has is also sampled following
# the original distribution of your dataset.

# %%
sampled['users']
# Out:
#    user_id country gender  age
# 0        0      ES    NaN   36
# 1        1      ES      M   20
# 2        2      UK    NaN   26
# 3        3      US      F   22
# 4        4      DE    NaN   53
# 5        5      DE      M   45
# 6        6      UK      F   26
# 7        7      FR    NaN   44
# 8        8      US    NaN   19
# 9        9      UK      M   36

# %%
sampled['sessions'].head(10)
# Out:
#    session_id  user_id  device       os
# 0           0        0  mobile  android
# 1           1        0  mobile  android
# 2           2        1  tablet      ios
# 3           3        1  tablet      ios
# 4           4        2  mobile  android
# 5           5        3  tablet      ios
# 6           6        4  tablet      ios
# 7           7        5  mobile  android
# 8           8        6  mobile  android
# 9           9        6  mobile  android

# %%
sampled['transactions'].head(10)
# Out:
#    transaction_id  session_id                     timestamp     amount  \
# 0               0           0 2019-01-30 08:31:39.005860864  85.839785
# 1               1           1 2019-01-30 08:31:35.447443968  86.575069
# 2               2           2 2019-01-10 22:59:13.504031744  94.130859
# 3               3           2 2019-01-10 22:59:13.504031744  94.131163
# 4               4           3 2019-01-10 23:00:13.566702592  94.130507
# 5               5           3 2019-01-10 23:00:13.566702592  94.130290
# 6               6           5                           NaT  83.913626
# 7               7           6 2019-01-14 04:23:50.785624064  99.802537
# 8               8           6 2019-01-14 04:23:50.788062208  99.807132
# 9               9           7 2019-01-14 20:10:39.639778816  88.421176
#
#    approved
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True

# %% [markdown]
# ## Saving and Loading your model

# %% [markdown]
# In some cases, you might want to save the fitted SDV instance to be able to generate synthetic data from
# it later or on a different system.
#
# In order to do so, you can save your fitted `SDV` instance for later usage using the `save` method of your
# instance.

# %%
sdv.save('sdv.pkl')

# %% [markdown]
# The generated `pkl` file will not include any of the original data in it, so it can be
# safely sent to where the synthetic data will be generated without any privacy concerns.

# %% [markdown]
# Later on, in order to sample data from the fitted model, we will first need to load it from its
# `pkl` file.

# %%
sdv = SDV.load('sdv.pkl')

# %% [markdown]
# After loading the instance, we can sample synthetic data using its `sample_all` method like before.

# %%
sampled = sdv.sample_all(5)

# %%
display_tables(sampled)
# Out:
# <table><tr><td><b>users</b></td><td><b>sessions</b></td><td><b>transactions</b></td></tr><tr><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>country</th>
#       <th>gender</th>
#       <th>age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10</td>
#       <td>UK</td>
#       <td>M</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11</td>
#       <td>US</td>
#       <td>F</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12</td>
#       <td>BG</td>
#       <td>F</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>13</td>
#       <td>US</td>
#       <td>M</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14</td>
#       <td>FR</td>
#       <td>NaN</td>
#       <td>52</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>session_id</th>
#       <th>user_id</th>
#       <th>device</th>
#       <th>os</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12</td>
#       <td>10</td>
#       <td>mobile</td>
#       <td>android</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>13</td>
#       <td>11</td>
#       <td>mobile</td>
#       <td>android</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14</td>
#       <td>12</td>
#       <td>tablet</td>
#       <td>ios</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>15</td>
#       <td>13</td>
#       <td>tablet</td>
#       <td>ios</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16</td>
#       <td>14</td>
#       <td>tablet</td>
#       <td>ios</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>transaction_id</th>
#       <th>session_id</th>
#       <th>timestamp</th>
#       <th>amount</th>
#       <th>approved</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14</td>
#       <td>14</td>
#       <td>NaT</td>
#       <td>7525.522272</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>15</td>
#       <td>14</td>
#       <td>NaT</td>
#       <td>8845.816361</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16</td>
#       <td>15</td>
#       <td>2019-01-14 03:09:54</td>
#       <td>90.413157</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17</td>
#       <td>15</td>
#       <td>2019-01-14 03:09:54</td>
#       <td>90.419682</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>18</td>
#       <td>16</td>
#       <td>2019-01-08 21:19:09</td>
#       <td>101.274093</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>19</td>
#       <td>16</td>
#       <td>2019-01-08 21:19:09</td>
#       <td>101.286008</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
